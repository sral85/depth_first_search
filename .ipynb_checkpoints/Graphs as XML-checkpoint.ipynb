# %% [markdown]
# # Depth First Search - Preparations

# %% [markdown]
# Here we want to implement a depth first search algorithm to find all vertices in an digraph, which are reachable from a given vertex.

# %% [markdown]
# ## Definition of a Class for Vertices and Graphs

# %% [markdown]
# At first we define a class for a single vertex. We will store its name, a label and its adjecent vertices. Hence we will not introduce an edge class.

# %%
class node():
    def __init__(self, name, label, adjacent):
        self.name = name
        self.label = label
        self.adjacent = set(adjacent)
        
    def add(self, vertex):
        self.adjacent.add(vertex)

# %% [markdown]
# Here is our definition of a class for graphs.

# %%
#Import XML-Parser
from xml.dom import minidom

#Import functionality to visualize graphs
path = 'F:/Program Files (x86)/Graphviz2.38/bin/'
import os
os.environ["PATH"] += os.pathsep + path
from graphviz import Digraph
from IPython.display import Image

#Create class
class graph():
    def __init__(self, path_to_xml):
        self.vertices = {}
        
        graph_xml = minidom.parse(path_to_xml)
        vertex_list = graph_xml.getElementsByTagName('vertex')
        self.vertices = {}
        for x in vertex_list:
            self.vertices[x.getAttribute('id')] = node(x.getAttribute('id'), x.getAttribute('label'), set())
    
        edge_list = graph_xml.getElementsByTagName('edge')
        for x in edge_list:
            self.vertices[x.getAttribute('tail')].add(x.getAttribute('head'))
          
    def to_png(self, color_dict = {}):     
        """
        This function takes a dictionary of vertices and saves the graph with a picture locally.
        """
        dot = Digraph(format='png')

        for key, node in self.vertices.items():
            if node.name in color_dict.keys():
                dot.node(node.name, node.label, style='filled', fillcolor=color_dict[node.name])
            else:
                dot.node(node.name, node.label)
            for x in node.adjacent:
                dot.edge(key, x)

        path_graph = dot.render('pictures/graph.gv', view=False)
        return(Image(path_graph))
    
    
    def dfs(self, init_vertex_name):
        """
        Implementation of depth first search.
        """
        visited = set()

        stack = [init_vertex_name]
        reachable = set()
    
        while stack != []:
            current_vertex_name = stack.pop()
            if current_vertex_name in visited:
                pass
            else:
                visited.add(current_vertex_name)
                for x in self.vertices[current_vertex_name].adjacent:
                    if x not in visited:
                        stack.append(x)
                        reachable.add(x)
                    
        return(reachable)

# %% [markdown]
# # Depth First Search Example

# %% [markdown]
# Next we read the graph which is stored in an xml file. We use the parser minidom from the xml.dom module. Note that we use digraphs.

# %%
file = 'graph_data.xml'
g = graph(file)

# %%
g.to_png()

# %%
from ipywidgets import interact

def f(init_vertex):
    reachable = g.dfs(init_vertex)
    color_dict = {x: 'blue' for x in reachable}
    color_dict[init_vertex] = 'grey'
    
    return(g.to_png(color_dict))

# %%
print('Please enter the initial node!')
interact(f, init_vertex = [x for x in g.vertices], manual=False);
# Out:
# Please enter the initial node!
# A Jupyter Widget
